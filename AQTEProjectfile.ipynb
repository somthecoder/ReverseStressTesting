# %% [markdown]
# # AQTE Advanced Risk Analysis Project

# %% [markdown]
# ### 1. Data

# %% [markdown]
# ### 2. Variables

# %% [markdown]
# ### 3. Feature Analysis

# %% [markdown]
# ### 4. Feature Selection

# %% [markdown]
# ### 5. Feature Matrix Selection- Backward Elimination

# %% [markdown]
# ### 6. Model
